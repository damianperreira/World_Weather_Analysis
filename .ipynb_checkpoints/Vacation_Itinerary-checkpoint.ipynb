# %% [markdown]
# ### Instructions Part 3
# Create a Travel Itinerary with a Corresponding Map
# 1. Create a new Jupyter Notebook file and label it Vacation_Itinerary.ipynb.

# %%
# dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
from citipy import citipy
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
from config import g_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %% [markdown]
# 2. Import the WeatherPy_vacation.csv file as a new DataFrame.

# %%
data_df = pd.read_csv("data/WeatherPy_vacation.csv") 
data_df
# Out:
#      City_ID            City Country  Max Temp    Lat     Lng  \
# 0          0           Kapaa      US     80.60  22.08 -159.32
# 1          3    Kudahuvadhoo      MV     82.17   2.67   72.89
# 2          5        Araouane      ML     76.30  18.90   -3.53
# 3          6          Katobu      ID     85.78  -4.94  122.53
# 4          8  Puerto%20Ayora      EC     75.20  -0.74  -90.35
# ..       ...             ...     ...       ...    ...     ...
# 202      551          Garowe      SO     71.51   8.41   48.48
# 203      552      San%20Juan      AR     84.72 -31.54  -68.53
# 204      554      Pandharpur      IN     70.93  17.68   75.33
# 205      557     Narsipatnam      IN     73.40  17.67   82.61
# 206      559          Dwarka      IN     71.67  28.58   77.04
#
#     Current Description                                     Hotel Name
# 0         moderate rain  Courtyard by Marriott Kaua'i at Coconut Beach
# 1       overcast clouds                            Orange Inn Maldives
# ...

# %% [markdown]
# 3. From the vacation search map:
# Choose at least four cities in close proximity on your map that are on the same continent that a customer might travel to, and then create a directions layer map.

# %%
#Hint - Filter the DataFrame for each city you want to go to and create separate DataFrames for each city

#citiesall = data_df[data_df['Country']=='US']
#citiesall

#Kahului
#Kahului = data_df[data_df['City']=='Kahului'] #(20.89,-156.47)
#Kahului

#Ahuimanu
#Ahuimanu = data_df[data_df['City']=='Ahuimanu'] #(21.44,-157.84)
#Ahuimanu

#Albany
#Albany = data_df[data_df['City']=='Albany'] #(42.65,-73.75)
#Albany

#Kodiak
#Kodiak = data_df[data_df['City']=='Kodiak'] #(39.95,-94.76)
#Kodiak

# Hint - Use the directions Layer instructions from the gmaps documentation

# %%
# Latitude-longitude pairs
Kahului = (20.89,-156.47)
Ahuimanu = (21.44,-157.84)

# Add a pop-up marker for each city
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in data_df.iterrows()]
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = data_df[["Lat", "Lng"]]
max_temp = data_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
#             max_intensity=300, point_radius=4)
#marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
Kahului2Ahuimanu = gmaps.directions_layer(Kahului, Ahuimanu)

#fig.add_layer(heat_layer)
#fig.add_layer(marker_layer)
fig.add_layer(Kahului2Ahuimanu)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
