# %% [markdown]
# ## Module 6 Challenge
#
# ### Part 1 Instructions
# Get the Weather Description and Amount of Precipitation for Each City (Using markdown cells for better presentation)
# 1. Create a new Jupyter Notebook file and name it Weather_Database.ipynb.

# %%
# Import the dependencies and setup
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Output File (CSV)
output_data_file = "WeatherPy_challenge.csv"

requests.__version__
# Out:
# '2.22.0'

# %% [markdown]
# #### 2. Generate a new set of 1,500 random latitudes and longitudes.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %% [markdown]
# #### 3. Get the nearest city using the citipy module.

# %%
# Create a list to hold the city data
cities = []

# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # Replace spaces with %20 to create url correctly 
    city = city.replace(" ", "%20")

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 625

# %% [markdown]
# #### 4. Perform an API call with the OpenWeatherMap.

# %%
# Starting URL for Weather Map API Call.
#url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91

# %% [markdown]
# #### 5. Retrieve the following information from the API call:

# %%
"""
Latitude and longitude
Maximum temperature
Percent humidity
Percent cloudiness
Wind speed
Weather description (e.g., clouds, fog, light rain, clear sky)
Using a try-except block, 
    if it is raining, get the amount of rainfall in inches for the last three hours. 
    If it is not raining, add 0 inches for the city.
Using a try-except block, 
    if it is snowing, get the amount of snow in inches for the last three hours. 
    If it is not snowing, add 0 inches for the city."""

print(url)
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(list(cities)):
   # Group cities in sets of 50 for logging purposes.
   if (i % 50 == 0 and i >= 50):
       set_count += 1
       record_count = 1
   # Create endpoint URL with each city.
   city_url = url + "&q=" + city
   # Log the URL, record, and set numbers and the city.
   print(f"Processing Record {record_count} of Set {set_count} | {city}")
   # Add 1 to the record count.
   record_count += 1
# Run an API request for each of the cities.
   try:
       print(city_url)
       # Parse the JSON and retrieve data.
       city_weather = requests.get(city_url).json()
       # Parse out the needed data.
       city_lat = city_weather["coord"]["lat"]
       city_lng = city_weather["coord"]["lon"]
       city_max_temp = city_weather["main"]["temp_max"]
       city_humidity = city_weather["main"]["humidity"]
       city_clouds = city_weather["clouds"]["all"]
       city_wind = city_weather["wind"]["speed"]
       city_country = city_weather["sys"]["country"]
    #Amik had this:
#        city_description = city_weather["weather"]["description"]
    #Nate changed to this; note the "weather" object is a *list*, not a *dict*; so we use [0]
       city_description = city_weather["weather"][0]["description"]
    #Nate removed these; some cities don't have rain reports
       #city_rain = city_weather["rain"][0]["3h"]
       #city_snow = city_weather["snow"][0]["3h"]
       # Convert the date to ISO standard.
       city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       # Append the city information into city_data list.
       city_data.append({"City": city.title(),
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_description,
                         #Nate removed these; some cities don't have rain reports
                         #"Rain inches (last 3 hrs)": city_rain,
                         #"Snow inches (last 3 hrs)": city_snow
                        })
# If an error is experienced, skip the city.
   except Exception as e:
       print(e)
       pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kapaa
# Processing Record 2 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=saint-philippe
# Processing Record 3 of Set 1 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=havre-saint-pierre
# Processing Record 4 of Set 1 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kudahuvadhoo
# Processing Record 5 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ushuaia
# Processing Record 6 of Set 1 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=araouane
# Processing Record 7 of Set 1 | katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=katobu
# Processing Record 8 of Set 1 | east%20london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=east%20london
# Processing Record 9 of Set 1 | puerto%20ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=puerto%20ayora
# Processing Record 10 of Set 1 | una
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=una
# Processing Record 11 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mataura
# Processing Record 12 of Set 1 | pasni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=pasni
# Processing Record 13 of Set 1 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=pisco
# Processing Record 14 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=tuktoyaktuk
# Processing Record 15 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=hobart
# Processing Record 16 of Set 1 | norman%20wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=norman%20wells
# Processing Record 17 of Set 1 | nelson%20bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=nelson%20bay
# Processing Record 18 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=nikolskoye
# Processing Record 19 of Set 1 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=itoman
# Processing Record 20 of Set 1 | umm%20lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=umm%20lajj
# Processing Record 21 of Set 1 | ridgecrest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ridgecrest
# Processing Record 22 of Set 1 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=karratha
# Processing Record 23 of Set 1 | saint%20george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=saint%20george
# Processing Record 24 of Set 1 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=okhotsk
# Processing Record 25 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=hermanus
# Processing Record 26 of Set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=barentsburg
# 'coord'
# Processing Record 27 of Set 1 | cabo%20san%20lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=cabo%20san%20lucas
# Processing Record 28 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=hilo
# Processing Record 29 of Set 1 | magadan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=magadan
# Processing Record 30 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=barrow
# Processing Record 31 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=khatanga
# Processing Record 32 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=rikitea
# Processing Record 33 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=bethel
# Processing Record 34 of Set 1 | port%20alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=port%20alfred
# Processing Record 35 of Set 1 | ende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ende
# Processing Record 36 of Set 1 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=tiarei
# Processing Record 37 of Set 1 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=paamiut
# Processing Record 38 of Set 1 | fallon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=fallon
# Processing Record 39 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=jamestown
# Processing Record 40 of Set 1 | pouebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=pouebo
# Processing Record 41 of Set 1 | ponta%20do%20sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ponta%20do%20sol
# Processing Record 42 of Set 1 | timiryazevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=timiryazevskiy
# Processing Record 43 of Set 1 | ponta%20delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ponta%20delgada
# Processing Record 44 of Set 1 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=faya
# Processing Record 45 of Set 1 | vikramasingapuram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=vikramasingapuram
# Processing Record 46 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=busselton
# Processing Record 47 of Set 1 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sentyabrskiy
# 'coord'
# Processing Record 48 of Set 1 | buribay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=buribay
# Processing Record 49 of Set 1 | la%20ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=la%20ronge
# Processing Record 50 of Set 1 | juazeiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=juazeiro
# Processing Record 1 of Set 2 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=cherskiy
# Processing Record 2 of Set 2 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=yulara
# Processing Record 3 of Set 2 | road%20town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=road%20town
# Processing Record 4 of Set 2 | punta%20arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=punta%20arenas
# Processing Record 5 of Set 2 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=talnakh
# Processing Record 6 of Set 2 | mauriti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mauriti
# Processing Record 7 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=bredasdorp
# Processing Record 8 of Set 2 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=nizhneyansk
# 'coord'
# Processing Record 9 of Set 2 | cape%20town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=cape%20town
# Processing Record 10 of Set 2 | sao%20joao%20da%20barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sao%20joao%20da%20barra
# Processing Record 11 of Set 2 | arona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=arona
# Processing Record 12 of Set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=thompson
# Processing Record 13 of Set 2 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=tiksi
# Processing Record 14 of Set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=bluff
# Processing Record 15 of Set 2 | cockburn%20town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=cockburn%20town
# Processing Record 16 of Set 2 | kuzhithurai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kuzhithurai
# Processing Record 17 of Set 2 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=nome
# Processing Record 18 of Set 2 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=qasigiannguit
# Processing Record 19 of Set 2 | morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=morondava
# Processing Record 20 of Set 2 | umm%20durman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=umm%20durman
# 'coord'
# Processing Record 21 of Set 2 | calatayud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=calatayud
# Processing Record 22 of Set 2 | lethem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=lethem
# Processing Record 23 of Set 2 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=namatanai
# Processing Record 24 of Set 2 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=dunedin
# Processing Record 25 of Set 2 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=vaini
# Processing Record 26 of Set 2 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=goderich
# Processing Record 27 of Set 2 | mindelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mindelo
# Processing Record 28 of Set 2 | santa%20eulalia%20del%20rio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=santa%20eulalia%20del%20rio
# 'coord'
# Processing Record 29 of Set 2 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=marcona
# 'coord'
# Processing Record 30 of Set 2 | nurobod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=nurobod
# Processing Record 31 of Set 2 | san%20lawrenz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=san%20lawrenz
# Processing Record 32 of Set 2 | acarau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=acarau
# 'coord'
# Processing Record 33 of Set 2 | hazorasp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=hazorasp
# Processing Record 34 of Set 2 | sioux%20lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sioux%20lookout
# Processing Record 35 of Set 2 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=coquimbo
# Processing Record 36 of Set 2 | grafenau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=grafenau
# Processing Record 37 of Set 2 | new%20norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=new%20norfolk
# Processing Record 38 of Set 2 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=vaitupu
# 'coord'
# Processing Record 39 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=tasiilaq
# Processing Record 40 of Set 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=avarua
# Processing Record 41 of Set 2 | xam%20nua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=xam%20nua
# Processing Record 42 of Set 2 | sehithwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sehithwa
# Processing Record 43 of Set 2 | mocuba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mocuba
# Processing Record 44 of Set 2 | quanzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=quanzhou
# Processing Record 45 of Set 2 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=portland
# Processing Record 46 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=qaanaaq
# Processing Record 47 of Set 2 | pleasant%20point
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=pleasant%20point
# Processing Record 48 of Set 2 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=severo-kurilsk
# Processing Record 49 of Set 2 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=meulaboh
# Processing Record 50 of Set 2 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=margate
# Processing Record 1 of Set 3 | mariara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mariara
# Processing Record 2 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=carnarvon
# Processing Record 3 of Set 3 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=atuona
# Processing Record 4 of Set 3 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=fairbanks
# Processing Record 5 of Set 3 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=yellowknife
# Processing Record 6 of Set 3 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=skjervoy
# Processing Record 7 of Set 3 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=westport
# Processing Record 8 of Set 3 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kavaratti
# Processing Record 9 of Set 3 | aflu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=aflu
# 'coord'
# Processing Record 10 of Set 3 | ossora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ossora
# Processing Record 11 of Set 3 | asosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=asosa
# Processing Record 12 of Set 3 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=halalo
# 'coord'
# Processing Record 13 of Set 3 | mar%20del%20plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mar%20del%20plata
# Processing Record 14 of Set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=lebu
# Processing Record 15 of Set 3 | erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=erzin
# Processing Record 16 of Set 3 | clyde%20river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=clyde%20river
# Processing Record 17 of Set 3 | trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=trinidad
# Processing Record 18 of Set 3 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=avera
# Processing Record 19 of Set 3 | cambridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=cambridge
# Processing Record 20 of Set 3 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=toliary
# 'coord'
# Processing Record 21 of Set 3 | satipo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=satipo
# Processing Record 22 of Set 3 | gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=gigmoto
# Processing Record 23 of Set 3 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=palabuhanratu
# 'coord'
# Processing Record 24 of Set 3 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mahebourg
# Processing Record 25 of Set 3 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=souillac
# Processing Record 26 of Set 3 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=provideniya
# Processing Record 27 of Set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=hithadhoo
# Processing Record 28 of Set 3 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=saint-georges
# Processing Record 29 of Set 3 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=tautira
# Processing Record 30 of Set 3 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=constitucion
# Processing Record 31 of Set 3 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=katsuura
# Processing Record 32 of Set 3 | caceres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=caceres
# Processing Record 33 of Set 3 | mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mercedes
# Processing Record 34 of Set 3 | carlos%20chagas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=carlos%20chagas
# Processing Record 35 of Set 3 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=umzimvubu
# 'coord'
# Processing Record 36 of Set 3 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ostrovnoy
# Processing Record 37 of Set 3 | develi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=develi
# Processing Record 38 of Set 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=longyearbyen
# Processing Record 39 of Set 3 | bontang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=bontang
# Processing Record 40 of Set 3 | abu%20dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=abu%20dhabi
# Processing Record 41 of Set 3 | tsiroanomandidy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=tsiroanomandidy
# Processing Record 42 of Set 3 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=amahai
# Processing Record 43 of Set 3 | ribeira%20grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ribeira%20grande
# Processing Record 44 of Set 3 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=bambanglipuro
# Processing Record 45 of Set 3 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=adrar
# Processing Record 46 of Set 3 | port%20augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=port%20augusta
# Processing Record 47 of Set 3 | comodoro%20rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=comodoro%20rivadavia
# Processing Record 48 of Set 3 | susehri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=susehri
# Processing Record 49 of Set 3 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ilulissat
# Processing Record 50 of Set 3 | bardiyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=bardiyah
# 'coord'
# Processing Record 1 of Set 4 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=caravelas
# Processing Record 2 of Set 4 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=seoul
# Processing Record 3 of Set 4 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=lavrentiya
# Processing Record 4 of Set 4 | phayao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=phayao
# Processing Record 5 of Set 4 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=cidreira
# Processing Record 6 of Set 4 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=saldanha
# Processing Record 7 of Set 4 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=asau
# 'coord'
# Processing Record 8 of Set 4 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=inhambane
# Processing Record 9 of Set 4 | lermontovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=lermontovka
# Processing Record 10 of Set 4 | arkhangelskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=arkhangelskoye
# Processing Record 11 of Set 4 | lima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=lima
# Processing Record 12 of Set 4 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=albany
# Processing Record 13 of Set 4 | arraial%20do%20cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=arraial%20do%20cabo
# Processing Record 14 of Set 4 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=castro
# Processing Record 15 of Set 4 | flin%20flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=flin%20flon
# Processing Record 16 of Set 4 | lazaro%20cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=lazaro%20cardenas
# Processing Record 17 of Set 4 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kodiak
# Processing Record 18 of Set 4 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=thinadhoo
# Processing Record 19 of Set 4 | sao%20mateus%20do%20sul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sao%20mateus%20do%20sul
# Processing Record 20 of Set 4 | iralaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=iralaya
# Processing Record 21 of Set 4 | bustonkala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=bustonkala
# 'coord'
# Processing Record 22 of Set 4 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=tumannyy
# 'coord'
# Processing Record 23 of Set 4 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=yerbogachen
# Processing Record 24 of Set 4 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=bengkulu
# 'coord'
# Processing Record 25 of Set 4 | cap%20malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=cap%20malheureux
# Processing Record 26 of Set 4 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=samusu
# 'coord'
# Processing Record 27 of Set 4 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=illoqqortoormiut
# 'coord'
# Processing Record 28 of Set 4 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sola
# Processing Record 29 of Set 4 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=narsaq
# Processing Record 30 of Set 4 | gardabani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=gardabani
# Processing Record 31 of Set 4 | half%20moon%20bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=half%20moon%20bay
# Processing Record 32 of Set 4 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=antofagasta
# Processing Record 33 of Set 4 | awbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=awbari
# Processing Record 34 of Set 4 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=alyangula
# Processing Record 35 of Set 4 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=airai
# Processing Record 36 of Set 4 | progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=progreso
# Processing Record 37 of Set 4 | minden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=minden
# Processing Record 38 of Set 4 | iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=iracoubo
# Processing Record 39 of Set 4 | khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=khasan
# Processing Record 40 of Set 4 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sitka
# Processing Record 41 of Set 4 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=klaksvik
# Processing Record 42 of Set 4 | haines%20junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=haines%20junction
# Processing Record 43 of Set 4 | ukiah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ukiah
# Processing Record 44 of Set 4 | saint-leu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=saint-leu
# Processing Record 45 of Set 4 | villa%20corzo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=villa%20corzo
# Processing Record 46 of Set 4 | kamaishi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kamaishi
# Processing Record 47 of Set 4 | ankang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ankang
# Processing Record 48 of Set 4 | basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=basco
# Processing Record 49 of Set 4 | kisujszallas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kisujszallas
# Processing Record 50 of Set 4 | banepa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=banepa
# Processing Record 1 of Set 5 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=maldonado
# Processing Record 2 of Set 5 | puerto%20del%20rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=puerto%20del%20rosario
# Processing Record 3 of Set 5 | taber
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=taber
# Processing Record 4 of Set 5 | sainte-suzanne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sainte-suzanne
# Processing Record 5 of Set 5 | angoche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=angoche
# Processing Record 6 of Set 5 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mitu
# Processing Record 7 of Set 5 | nanfeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=nanfeng
# Processing Record 8 of Set 5 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=butaritari
# Processing Record 9 of Set 5 | aldine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=aldine
# Processing Record 10 of Set 5 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=dikson
# Processing Record 11 of Set 5 | port%20elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=port%20elizabeth
# Processing Record 12 of Set 5 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=leningradskiy
# Processing Record 13 of Set 5 | blessington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=blessington
# Processing Record 14 of Set 5 | torva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=torva
# Processing Record 15 of Set 5 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=chuy
# Processing Record 16 of Set 5 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=dingle
# Processing Record 17 of Set 5 | ekhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ekhabi
# Processing Record 18 of Set 5 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=georgetown
# Processing Record 19 of Set 5 | ratnagiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ratnagiri
# Processing Record 20 of Set 5 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=nuuk
# Processing Record 21 of Set 5 | patacamaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=patacamaya
# Processing Record 22 of Set 5 | tutin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=tutin
# Processing Record 23 of Set 5 | calais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=calais
# Processing Record 24 of Set 5 | neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=neiafu
# Processing Record 25 of Set 5 | mandaguacu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mandaguacu
# Processing Record 26 of Set 5 | port%20macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=port%20macquarie
# Processing Record 27 of Set 5 | san%20patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=san%20patricio
# Processing Record 28 of Set 5 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=upernavik
# Processing Record 29 of Set 5 | san%20vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=san%20vicente
# Processing Record 30 of Set 5 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=axim
# Processing Record 31 of Set 5 | mayskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mayskiy
# Processing Record 32 of Set 5 | walvis%20bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=walvis%20bay
# Processing Record 33 of Set 5 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ambon
# Processing Record 34 of Set 5 | atbasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=atbasar
# Processing Record 35 of Set 5 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=hasaki
# Processing Record 36 of Set 5 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=chokurdakh
# Processing Record 37 of Set 5 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=camacha
# Processing Record 38 of Set 5 | iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=iskateley
# Processing Record 39 of Set 5 | roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=roebourne
# Processing Record 40 of Set 5 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=coihaique
# Processing Record 41 of Set 5 | jinchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=jinchang
# Processing Record 42 of Set 5 | vrangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=vrangel
# Processing Record 43 of Set 5 | lenger
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=lenger
# Processing Record 44 of Set 5 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=nabire
# Processing Record 45 of Set 5 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=taolanaro
# 'coord'
# Processing Record 46 of Set 5 | onega
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=onega
# Processing Record 47 of Set 5 | grand%20gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=grand%20gaube
# Processing Record 48 of Set 5 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ahipara
# Processing Record 49 of Set 5 | launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=launceston
# Processing Record 50 of Set 5 | san%20cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=san%20cristobal
# Processing Record 1 of Set 6 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=touros
# Processing Record 2 of Set 6 | hervey%20bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=hervey%20bay
# Processing Record 3 of Set 6 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=buraydah
# Processing Record 4 of Set 6 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=geraldton
# Processing Record 5 of Set 6 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=buala
# Processing Record 6 of Set 6 | mys%20shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mys%20shmidta
# 'coord'
# Processing Record 7 of Set 6 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=bathsheba
# Processing Record 8 of Set 6 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=lagoa
# Processing Record 9 of Set 6 | galbinasi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=galbinasi
# Processing Record 10 of Set 6 | jurado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=jurado
# 'coord'
# Processing Record 11 of Set 6 | illela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=illela
# Processing Record 12 of Set 6 | bukachacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=bukachacha
# Processing Record 13 of Set 6 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=krasnoselkup
# 'coord'
# Processing Record 14 of Set 6 | urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=urumqi
# 'coord'
# Processing Record 15 of Set 6 | marsh%20harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=marsh%20harbour
# Processing Record 16 of Set 6 | ocampo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ocampo
# Processing Record 17 of Set 6 | antequera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=antequera
# Processing Record 18 of Set 6 | najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=najran
# Processing Record 19 of Set 6 | chippewa%20falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=chippewa%20falls
# Processing Record 20 of Set 6 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=fortuna
# Processing Record 21 of Set 6 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mitsamiouli
# Processing Record 22 of Set 6 | carmen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=carmen
# Processing Record 23 of Set 6 | mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mabaruma
# Processing Record 24 of Set 6 | wenzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=wenzhou
# Processing Record 25 of Set 6 | sholapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sholapur
# 'coord'
# Processing Record 26 of Set 6 | tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=tiznit
# Processing Record 27 of Set 6 | mattawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mattawa
# Processing Record 28 of Set 6 | grand%20river%20south%20east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=grand%20river%20south%20east
# 'coord'
# Processing Record 29 of Set 6 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=tomatlan
# Processing Record 30 of Set 6 | la%20brea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=la%20brea
# Processing Record 31 of Set 6 | kikwit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kikwit
# Processing Record 32 of Set 6 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=tsihombe
# 'coord'
# Processing Record 33 of Set 6 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=pangnirtung
# Processing Record 34 of Set 6 | port%20hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=port%20hedland
# Processing Record 35 of Set 6 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=hami
# Processing Record 36 of Set 6 | bambous%20virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=bambous%20virieux
# Processing Record 37 of Set 6 | lake%20city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=lake%20city
# Processing Record 38 of Set 6 | khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=khandyga
# Processing Record 39 of Set 6 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=berlevag
# Processing Record 40 of Set 6 | wulanhaote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=wulanhaote
# 'coord'
# Processing Record 41 of Set 6 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=viedma
# Processing Record 42 of Set 6 | ust-ishim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ust-ishim
# Processing Record 43 of Set 6 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mecca
# Processing Record 44 of Set 6 | chateauroux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=chateauroux
# Processing Record 45 of Set 6 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=pevek
# Processing Record 46 of Set 6 | kazalinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kazalinsk
# 'coord'
# Processing Record 47 of Set 6 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=husavik
# Processing Record 48 of Set 6 | nguiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=nguiu
# 'coord'
# Processing Record 49 of Set 6 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=klyuchi
# Processing Record 50 of Set 6 | los%20llanos%20de%20aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=los%20llanos%20de%20aridane
# Processing Record 1 of Set 7 | fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=fare
# Processing Record 2 of Set 7 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=esperance
# Processing Record 3 of Set 7 | asfi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=asfi
# 'coord'
# Processing Record 4 of Set 7 | niquelandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=niquelandia
# Processing Record 5 of Set 7 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kaitangata
# Processing Record 6 of Set 7 | kailua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kailua
# Processing Record 7 of Set 7 | vila%20velha
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kirakira
# Processing Record 25 of Set 11 | gaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=gaya
# Processing Record 26 of Set 11 | smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=smithers
# Processing Record 27 of Set 11 | sao%20jose%20do%20belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sao%20jose%20do%20belmonte
# Processing Record 28 of Set 11 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=korla
# 'coord'
# Processing Record 29 of Set 11 | sao%20jose%20do%20egito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sao%20jose%20do%20egito
# Processing Record 30 of Set 11 | miles%20city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=miles%20city
# Processing Record 31 of Set 11 | ternate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ternate
# Processing Record 32 of Set 11 | dauriya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=dauriya
# Processing Record 33 of Set 11 | falaleu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=falaleu
# 'coord'
# Processing Record 34 of Set 11 | stenlille
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=stenlille
# Processing Record 35 of Set 11 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=beloha
# Processing Record 36 of Set 11 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=salalah
# Processing Record 37 of Set 11 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=gizo
# Processing Record 38 of Set 11 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=saint-francois
# Processing Record 39 of Set 11 | puri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=puri
# Processing Record 40 of Set 11 | ruteng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ruteng
# Processing Record 41 of Set 11 | ashland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ashland
# Processing Record 42 of Set 11 | albemarle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=albemarle
# Processing Record 43 of Set 11 | eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=eyl
# Processing Record 44 of Set 11 | murovani%20kurylivtsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=murovani%20kurylivtsi
# Processing Record 45 of Set 11 | gajraula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=gajraula
# Processing Record 46 of Set 11 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=belmonte
# Processing Record 47 of Set 11 | dharchula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=dharchula
# Processing Record 48 of Set 11 | richards%20bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=richards%20bay
# Processing Record 49 of Set 11 | uusikaupunki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=uusikaupunki
# Processing Record 50 of Set 11 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kamenskoye
# 'coord'
# Processing Record 1 of Set 12 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=qaqortoq
# Processing Record 2 of Set 12 | haibowan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=haibowan
# 'coord'
# Processing Record 3 of Set 12 | masalli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=masalli
# Processing Record 4 of Set 12 | mbandaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mbandaka
# Processing Record 5 of Set 12 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=laguna
# Processing Record 6 of Set 12 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=northam
# Processing Record 7 of Set 12 | sivas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sivas
# Processing Record 8 of Set 12 | santa%20cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=santa%20cruz
# Processing Record 9 of Set 12 | biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=biak
# Processing Record 10 of Set 12 | barao%20de%20melgaco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=barao%20de%20melgaco
# Processing Record 11 of Set 12 | virginia%20beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=virginia%20beach
# Processing Record 12 of Set 12 | lakota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=lakota
# Processing Record 13 of Set 12 | pasighat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=pasighat
# Processing Record 14 of Set 12 | matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=matay
# Processing Record 15 of Set 12 | benghazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=benghazi
# Processing Record 16 of Set 12 | linjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=linjiang
# Processing Record 17 of Set 12 | port-de-bouc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=port-de-bouc
# Processing Record 18 of Set 12 | soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=soyo
# Processing Record 19 of Set 12 | gualaquiza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=gualaquiza
# Processing Record 20 of Set 12 | platteville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=platteville
# Processing Record 21 of Set 12 | la%20palma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=la%20palma
# Processing Record 22 of Set 12 | diffa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=diffa
# Processing Record 23 of Set 12 | burns%20lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=burns%20lake
# Processing Record 24 of Set 12 | hornepayne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=hornepayne
# Processing Record 25 of Set 12 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=wanning
# Processing Record 26 of Set 12 | lubao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=lubao
# Processing Record 27 of Set 12 | salobrena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=salobrena
# Processing Record 28 of Set 12 | oliveira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=oliveira
# Processing Record 29 of Set 12 | akhtubinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=akhtubinsk
# Processing Record 30 of Set 12 | oyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=oyama
# Processing Record 31 of Set 12 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=havelock
# Processing Record 32 of Set 12 | pacific%20grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=pacific%20grove
# Processing Record 33 of Set 12 | pousat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=pousat
# 'coord'
# Processing Record 34 of Set 12 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=beringovskiy
# Processing Record 35 of Set 12 | melchor%20de%20mencos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=melchor%20de%20mencos
# Processing Record 36 of Set 12 | beisfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=beisfjord
# Processing Record 37 of Set 12 | awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=awjilah
# Processing Record 38 of Set 12 | dickinson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=dickinson
# Processing Record 39 of Set 12 | carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=carutapera
# Processing Record 40 of Set 12 | sataua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sataua
# 'coord'
# Processing Record 41 of Set 12 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=hirara
# Processing Record 42 of Set 12 | sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sorvag
# 'coord'
# Processing Record 43 of Set 12 | gerash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=gerash
# Processing Record 44 of Set 12 | ubinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ubinskoye
# Processing Record 45 of Set 12 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sabang
# Processing Record 46 of Set 12 | verkhniye%20kigi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=verkhniye%20kigi
# Processing Record 47 of Set 12 | prince%20rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=prince%20rupert
# Processing Record 48 of Set 12 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sorland
# Processing Record 49 of Set 12 | cobourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=cobourg
# Processing Record 50 of Set 12 | taungdwingyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=taungdwingyi
# Processing Record 1 of Set 13 | poronaysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=poronaysk
# Processing Record 2 of Set 13 | ampanihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=ampanihy
# Processing Record 3 of Set 13 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=sobolevo
# Processing Record 4 of Set 13 | abu%20samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=abu%20samrah
# Processing Record 5 of Set 13 | lardos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=lardos
# Processing Record 6 of Set 13 | tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=tromso
# Processing Record 7 of Set 13 | san%20policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=san%20policarpo
# Processing Record 8 of Set 13 | emporia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=emporia
# Processing Record 9 of Set 13 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=padang
# Processing Record 10 of Set 13 | kysyl-syr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=kysyl-syr
# Processing Record 11 of Set 13 | dinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=dinga
# Processing Record 12 of Set 13 | zunyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=zunyi
# Processing Record 13 of Set 13 | gold%20coast
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=gold%20coast
# Processing Record 14 of Set 13 | mumford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=mumford
# Processing Record 15 of Set 13 | west%20fargo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=west%20fargo
# Processing Record 16 of Set 13 | garowe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=garowe
# Processing Record 17 of Set 13 | san%20juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=san%20juan
# Processing Record 18 of Set 13 | tarko-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=tarko-sale
# Processing Record 19 of Set 13 | pandharpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=pandharpur
# Processing Record 20 of Set 13 | bani%20walid
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=bani%20walid
# Processing Record 21 of Set 13 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=rocha
# Processing Record 22 of Set 13 | narsipatnam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=narsipatnam
# Processing Record 23 of Set 13 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=lata
# Processing Record 24 of Set 13 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=dwarka
# Processing Record 25 of Set 13 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=9c193d389a566882b7b6f26b1fcd7a91&q=matara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# #### 6. Add the data to a new DataFrame.

# %%
# Convert the array of dicts to DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City Country                 Date    Lat     Lng  Max Temp  \
# 0               Kapaa      US  2019-11-11 00:21:23  22.08 -159.32     80.60
# 1      Saint-Philippe      CA  2019-11-11 00:19:39  45.36  -73.48     43.00
# 2  Havre-Saint-Pierre      CA  2019-11-11 00:24:19  50.23  -63.60     32.00
# 3        Kudahuvadhoo      MV  2019-11-11 00:16:10   2.67   72.89     82.17
# 4             Ushuaia      AR  2019-11-11 00:23:31 -54.81  -68.31     57.20
# 5            Araouane      ML  2019-11-11 00:12:43  18.90   -3.53     76.30
# 6              Katobu      ID  2019-11-11 00:19:41  -4.94  122.53     85.78
# 7       East%20London      ZA  2019-11-11 00:21:17 -33.02   27.91     68.20
# 8      Puerto%20Ayora      EC  2019-11-11 00:19:25  -0.74  -90.35     75.20
# 9                 Una      IN  2019-11-11 00:24:20  31.47   76.27     56.80
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        94          90       10.29       moderate rain
# 1        78          90       11.41          light rain
# 2        82          90       13.87          light snow
# 3        73          98        5.55     overcast clouds
# 4        47           6       13.87           clear sky
# 5        13         100       11.99     overcast clouds
# 6        58          49        5.35    scattered clouds
# 7        81         100       21.41          light rain
# 8        69          75       13.87       broken clouds
# 9        60          85        2.93     overcast clouds

# %% [markdown]
# #### 7. Save the new DataFrame as a CSV file to be used for Part 2

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
